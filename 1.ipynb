# %% [markdown]
# Data Visualization is simply graphical representation of data or any information.
# That's where matplotlib is used.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt   # just importing a pyplot from matplotlib 
print("libraries imported")
# Out:
# libraries imported

# %% [markdown]
# Line Plot Chart :- Line plots are excellent for displaying trends or patterns over a continuous range. For example, you might use a line plot to show how a stock price changes over time.

# %%
country_population = [700,750,740,730,752,800,790]
country_population
# Out:
# [700, 750, 740, 730, 752, 800, 790]

# %%
# lineplot()

plt.plot(country_population)

# %%
plt.plot(country_population)
plt.show()

# %%
# let's consider 2d line chart
country_population = [700,750,740,730,752,800,820]
x_axis = [100,200,250,300,240,400,390]
plt.plot(x_axis,country_population)
plt.show()

# %%
# marking indicator point
country_population = [700,750,740,730,752,800,820]
x_axis = [100,200,250,300,240,400,390]
plt.plot(x_axis,country_population,marker="*",ms=15,mfc='yellow')  # ms = marker size, mfc = marker face color
plt.show()

# %%
country_population = [700,750,740,730,752,800,820]
x_axis = [100,200,250,300,240,400,390]
plt.plot(x_axis,country_population,marker="D",ms=15,mfc='yellow')  # ms = marker size, mfc = marker face color
# marker = "*", "v", "D", "p", "P" ....
plt.show()

# %%
country_population = [700,750,740,730,752,800,820]
x_axis = [100,200,250,300,240,400,390]
plt.plot(x_axis,country_population,marker="v",ms=15,mfc='yellow')  # ms = marker size, mfc = marker face color
plt.show()

# %% [markdown]
# label representation on axis

# %%
country_population = [700,750,740,730,752,800,820]
x_axis = [100,200,250,300,240,400,390]
plt.plot(x_axis,country_population,marker="p",ms=15,mfc='yellow')  # ms = marker size, mfc = marker face color
plt.xlabel("Axis-X")
plt.ylabel("country_population")
plt.show()

# %%
list1 = [100,400,300,400,100]
list2 = [1,1,2,3,3]
plt.plot(list2,list1)
plt.show()

# %% [markdown]
# Changing color of line and give title to graph and ls parameter

# %%
country_population = [700,750,740,730,752,800,820]
x_axis = [100,200,250,300,240,400,390]
plt.plot(x_axis,country_population,marker="*",ms=15,mfc='yellow',color='blue',ls = 'dashed',lw=4)  # ms = marker size, mfc = marker face color
plt.title("Lineplot Demo")
plt.xlabel("Axis-X")
plt.ylabel("country_population")
plt.show()
# ls = line style = dotted , dashed, solid(by default)
# lw = line width

# %% [markdown]
# BAR PLOT :-

# %%
country_population = [450,730,900,450,800]
country_name = ['Japan','bangladesh','india','nepal','china']

plt.bar(country_name,country_population)
plt.xlabel('name')
plt.ylabel('Population')
plt.show()

# %%
df = pd.read_csv('Used_Bikes.csv')
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df['brand'].value_counts()
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
name_of_brand = list(df['brand'].value_counts().keys())
name_of_brand
# Out:
# ['Bajaj',
#  'Royal Enfield',
#  'Hero',
#  'Honda',
#  'Yamaha',
#  'TVS',
#  'KTM',
#  'Suzuki',
#  'Harley-Davidson',
#  'Kawasaki',
#  'Hyosung',
#  'Mahindra',
#  'Benelli',
#  'Triumph',
#  'Ducati',
#  'BMW',
#  'Jawa',
#  'Indian',
#  'MV',
#  'Rajdoot',
#  'LML',
#  'Yezdi',
#  'Ideal']

# %%
no_of_values = list(df['brand'].value_counts().values)
no_of_values
# Out:
# [np.int64(2081),
#  np.int64(1346),
#  np.int64(1142),
#  np.int64(676),
#  np.int64(651),
#  np.int64(481),
#  np.int64(375),
#  np.int64(203),
#  np.int64(91),
#  np.int64(61),
#  np.int64(53),
#  np.int64(50),
#  np.int64(46),
#  np.int64(21),
#  np.int64(20),
#  np.int64(10),
#  np.int64(7),
#  np.int64(3),
#  np.int64(3),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1)]

# %%
plt.bar(name_of_brand,no_of_values)
plt.show()

# %%
# Removing overlapping of brand names in above diagram using rotation of ticks of axis x and y
plt.bar(name_of_brand,no_of_values)
plt.xticks(rotation = 80)
plt.show()

# %% [markdown]
# Designing bar graph

# %%
plt.figure(figsize=(10,4))  #(width,height)
plt.bar(name_of_brand,no_of_values,color='red',ec='black')
plt.xticks(rotation = 80)

# ec = edge color

plt.savefig('brandpopulation')  # save graph image with name of brandpopulation

plt.show()

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             6642
# Second Owner             588
# Third Owner               84
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
owners = list(df['owner'].value_counts().keys())
numbers = list(df['owner'].value_counts().values)
plt.xticks(rotation=75)
plt.xlabel('Owner')
plt.ylabel('Bike numbers')

plt.bar(owners,numbers,ec='black',lw=4)  #here lw use as edge width
# Out:
# <BarContainer object of 4 artists>

# %%
heartbeat = [750,750,750,750,750,750,745,750,750,760,750,750,747,780,730,750,750,760,750,750,750,750,750,750,750,750,750,750,750,750,745,750,750,760,750,750,747,780,730,750,750,760,750,750,750,750,750,750,750,750,750,750,750,750,745,750,750,760,750,750,747,780,730,750,750,760,750,750,750,750,750,750,750,750,750,750,750,750,745,750,750,760,750,750,747,780,730,750,750,760,750,750,750,750,750,750]
plt.plot(heartbeat)
plt.show()

# %%
# creating letter "A"
list1 = [0,1,2,3,1,3,4]
list2 = [0,100,200,100,100,100,0]
plt.plot(list1,list2)
plt.show()

# %% [markdown]
# DAY 2

# %% [markdown]
# Histogram

# %%
# numpy is important
age = np.random.randint(1,100,500)
age
# Out:
# array([10, 38, 34, 48, 81, 52, 94, 45,  3, 93,  5,  8, 92, 97, 64, 64, 16,
#        16, 73,  5, 54, 34, 11, 11,  8, 62, 87, 36, 55, 89, 84, 94, 86, 34,
#        84,  6, 62, 47, 72, 83,  1, 34, 98, 32,  3,  5, 78,  3, 90, 81, 46,
#        88, 45, 35, 46, 12, 60, 44, 95, 54, 65, 30, 86, 11, 92, 66, 41, 16,
#         2, 26, 32, 36, 22, 41, 60, 93, 92,  1, 51,  9, 31, 55, 53, 91, 97,
#        32, 98, 88, 86, 86, 33, 15, 44, 83, 62, 83, 42, 32, 42, 81, 55,  2,
#        29, 62, 18, 89, 38, 17, 44, 69, 82, 27, 37, 84, 25, 67, 42, 44, 36,
#        97,  9, 29, 12, 42, 96, 72, 50, 68, 96, 88, 38, 15, 38, 51, 42, 23,
#        24, 97, 36, 15, 19, 77, 76, 53, 14, 66, 83, 53, 18, 99,  2, 65, 68,
#        87, 40, 93, 37, 11, 55, 11, 24,  4, 54, 57, 95, 25, 41, 82, 92, 96,
#        45, 34, 26, 71, 36, 96, 37, 72, 23, 90, 64, 40, 13, 74, 12,  2, 95,
#        70,  7, 51,  6, 35, 49,  7, 94, 99, 82, 64, 57, 97, 24, 36, 57, 11,
# ...

# %%
bin = [0,18,30,50,70,90,100]  # range of bars 0 to 18 , 18 to 30 , 30 to 50 ....
plt.hist(age,bins = bin, ec ='black') # bins define range of bars in histogram
plt.show()

# %%
# default histogram 
plt.hist(age, ec ='black')
plt.show()

# %% [markdown]
# SCATTER PLOT

# %%
var1 = [25,41,63,96,45]
var2 = [45,63,65,25,75]

# (x-axis,y-axis)

plt.scatter(var1,var2)  
plt.xlabel('var1')
plt.ylabel('var2')
plt.show()

# %%
var1 = ['a','b','c','d','e']
var2 = [25,41,63,96,45]

plt.scatter(var1,var2)
plt.xlabel('var1')
plt.ylabel('var2')
plt.show()

# %%
df = pd.read_csv('Used_Bikes.csv')
df.drop_duplicates(inplace=True)
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
plt.scatter(df['price'],df['kms_driven'],color='blue')
plt.xlabel('price(in lakh)')
plt.ylabel('kms driven')
plt.show()

# %%
plt.scatter(df['power'],df['kms_driven'],color='blue')
plt.xlabel('power')
plt.ylabel('kms driven')
plt.show()

# %% [markdown]
# PIE PLOT :-

# %%
country_population = [450,730,900,450,800]
country_name = ['Japan','bangladesh','india','nepal','china']


plt.pie(country_population,labels=country_name)
plt.show()

# %%
# autopct = auto percentage (%2.2f%%)(2float,2 decimal)
plt.pie(country_population,labels=country_name,autopct="%2.2f%%")
plt.show()

# %%
country_population = [450,730,900,450,800]
country_name = ['Japan','bangladesh','india','nepal','china']

explosion = [0,0.1,0,0,0.2]

plt.pie(country_population,labels=country_name,autopct="%2.2f%%",explode=explosion)
plt.show()

# %%
plt.figure(figsize=(6,8))   #width,height
country_population = [450,730,900,450,800]
country_name = ['Japan','bangladesh','india','nepal','china']

explosion = [0,0.1,0,0,0.2]

plt.pie(country_population,labels=country_name,autopct="%2.2f%%",explode=explosion,wedgeprops={'ec':'black','lw':3},shadow=True)
plt.show()

# %% [markdown]
# BOX PLOT :-

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
ktm=df[df['brand']=="KTM"]
ktm
# Out:
#              bike_name     price        city  kms_driven         owner  age  \
# 33        KTM RC 390cc  180000.0        Pune     17700.0   First Owner  4.0
# 35      KTM Duke 200cc   70000.0      Nashik    100000.0  Second Owner  8.0
# 39    KTM RC 200cc ABS  179000.0   Bangalore      3400.0   First Owner  2.0
# 65      KTM Duke 200cc   94700.0    Baripara     32700.0   First Owner  4.0
# 83      KTM Duke 250cc  130000.0  Gandhidham     17500.0  Second Owner  4.0
# ...                ...       ...         ...         ...           ...  ...
# 9070      KTM RC 200cc  140000.0  Berhampore      2600.0   First Owner  6.0
# 9195    KTM Duke 200cc   70000.0       Thane     49347.0   First Owner  9.0
# 9255    KTM Duke 125cc  135000.0   Bangalore      1050.0   First Owner  3.0
# 9282    KTM Duke 390cc  139100.0       Delhi     25500.0   First Owner  5.0
# 9348    KTM Duke 390cc  195000.0      Mumbai      4568.0   First Owner  4.0
#
#       power brand
# 33    390.0   KTM
# ...

# %%
ktm[ktm['price']==ktm['price'].min()]
# Out:
#            bike_name    price    city  kms_driven        owner  age  power  \
# 7646  KTM Duke 200cc  55000.0  Mumbai     32000.0  Third Owner  9.0  200.0
#
#      brand
# 7646   KTM

# %%
ktm['price'].min()
# Out:
# np.float64(55000.0)

# %%
ktm['price'].max()
# Out:
# np.float64(860000.0)

# %%
ktm['price'].mean()
# Out:
# np.float64(147946.928)

# %%
ktm['price'].median()
# Out:
# np.float64(142600.0)

# %%
plt.boxplot(ktm['price'])
plt.ylabel('price(in million)')
plt.show()

# %% [markdown]
# Till now , we already learn line,bar,scattter,histogram,pie,box plots .
# And we don't need more than these plots in data science.
